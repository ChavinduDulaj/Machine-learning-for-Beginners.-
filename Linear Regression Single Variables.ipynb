# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv("dataset\homeprices.csv")
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %% [markdown]
# # Ploting the data using pyplot

# %%
# Scatter plot
plt.scatter(df.area, df.price, color='red', marker='+')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Scatter Plot of Area vs Price')

# Display the plot
plt.show()

# %% [markdown]
# # Training the dataset using Linear Regression model

# %%
# Assuming reg is your trained linear regression model
reg = linear_model.LinearRegression()
reg.fit(df[['area']], df['price'])

# Reshape the input to a 2D array
input_value = np.array(3300).reshape(1, -1)

# Make the prediction
prediction = reg.predict(input_value)

# Print the prediction
print(prediction)
# Out:
# [628715.75342466]
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %% [markdown]
# # ploting again after the prediction

# %%
# Scatter plot
plt.scatter(df.area, df.price, color='red', marker='+')
plt.xlabel('Area')
plt.ylabel('Price')
plt.title('Scatter Plot of Area vs Price')
plt.plot(df.area, reg.predict(df[['area']]), color='blue')
# Display the plot
plt.show()

# %% [markdown]
# # Checking the coefficients and intercept values

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
m = reg.coef_[0] #In scikit-learn, the coef_ attribute returns an array of coefficients when there are multiple features. In your case, you have a single feature ('area'), so the coef_ attribute returns an array with a single element.
c = reg.intercept_

# Get input from the user
x = float(input('Enter area for a land: '))

# Calculate the predicted price
y = (m * x) + c

print(f'Price for {x} area is {y}')
# Out:
# Enter area for a land: 3300
# Price for 3300.0 area is 628715.7534246575

# %%
# Reshape the input to a 2D array
input_value = np.array(5000).reshape(1, -1)

# Make the prediction
prediction = reg.predict(input_value)

# Print the prediction
print(prediction)
# Out:
# [859554.79452055]
# C:\Users\ASUS\anaconda3\Lib\site-packages\sklearn\base.py:464: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# The error is caused by the backslash in the file path.
# In the file path string 'dataset\areas.csv', the backslash is being treated as an escape character, and \a is interpreted as the ASCII bell character (bell alert).
#To resolve this, you can use a raw string by adding an 'r' before the string or use double backslashes:

# %%
d = pd.read_csv("dataset\\areas.csv")
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p = reg.predict(d)

# %% [markdown]
# # Creating new column for the exsisting dataframe

# %%
d['prices'] = p

# %%
d.to_csv("prediction.csv", index=False)
